# %%
! pip install html5lib
from bs4 import BeautifulSoup
import requests
import html5lib
import csv
# Out:
# ...
# <!DOCTYPE html>
# <html class="no-js" lang="en" prefix="lc: http://loc.gov/#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="$Revision$" name="version"/>
# <meta content="5C89FB9D99590AB2F55BD95C3A59BD81" name="msvalidate.01"/>
# <link href="http://purl.org/dc/elements/1.1/" rel="schema.dc" title="schema(DC)"/>
# <meta content="eng" name="dc.language"/>
# <meta content="Library of Congress, Washington, D.C. 20540 USA" name="dc.source"/>
# <meta content="libraryofcongress" property="fb:admins"/>
# <meta content="The Library of Congress" property="og:site_name"/>
# <meta content="article" property="og:type"/>
# <meta content="librarycongress" property="twitter:site"/>
# <title>Search results for  Cats, Available Online | Library of Congress</title>
# <meta content="Search results for Cats, Available Online " name="dc.title"/>
# ...

# %%
# section = soup.find("span", class_="item-description-title")
# print(section.prettify())
# Out:
# <div class="description">
#  <span class="original-format">
#   Photo, Print, Drawing
#  </span>
#  <div class="item-description">
#   <span class="item-description-title">
#    <a href="https://www.loc.gov/item/2004670356/" rel="http://www.loc.gov/item/2004670356/">
#     Cats
#    </a>
#   </span>
#   <span class="item-description-abstract">
#    1 print : tinted lithograph ; sheet 48.5 x 57.3 cm. | Print shows the faces and front paws of two sleeping cats.
#   </span>
#   <ul>
#    <li class="contributor">
#     <strong class="search-results-label">
#      Contributor:
#     </strong>
#     <span>
#      Hunter, Thomas - Hunter, Thomas, Approximately 1828-Approximately 1894
#     </span>
#    </li>
#    <li class="date">
#     <strong class="search-results-label">
#      Date:
#     </strong>
#     <span>
#      : 1874
#     </span>
#    </li>
#   </ul>
#  </div>
# </div>

# %%
# title = section.a.text
# print(title)
# Out:
#
#
#
#
#
#
#
#                     Cats

# %%
# description = section.find("span", class_="item-description-abstract").text
# print(description)
# Out:
#
#
#
#
#
#
#                           1 print : tinted lithograph ; sheet 48.5 x 57.3 cm. | Print shows the faces and front paws of two sleeping cats.

# %%
# link = section.a.get("rel")
# print(link)
# Out:
# ['http://www.loc.gov/item/2004670356/']

# %%
# csv_file = open("csm_scape.csv", "w", newline="", encoding="utf-8")
# csv_writer = csv.writer(csv_file)
# csv_writer.writerow([title, description, link])
# csv_file.close()

# %%
new_csv = open("cat_scrape.csv", "w", newline="", encoding="utf-8")
csv_writer = csv.writer(new_csv)
page = 1

while page != 6:
    source = requests.get(f"https://www.loc.gov/search/?q=cats&sp={page}").text
    soup = BeautifulSoup(source, "lxml")
    
    for element in soup.find_all("div", class_="item-description"):
        title = element.a.text.strip()
        try:
            description = element.find("span", class_="item-description-abstract").text.strip()
        except:
            description = "No description listed"
        link = element.a.get("rel")
        try:
#             contributor = element.find("strong", class_="search-results-label").text.strip()
            contributor = element.find("ul").text.strip()
    
        except:
            contributor = "No contributor listed"
        
#         print(f"{title}. {description} -- {link}")
        print(title)
        print(description)
        print(link)
        print(contributor)
        csv_writer.writerow([title, description, link, contributor])

    page += 1
csv_file.close()
# Out:
# Cats
# 1 print : tinted lithograph ; sheet 48.5 x 57.3 cm. | Print shows the faces and front paws of two sleeping cats.
# ['http://www.loc.gov/item/2004670356/']
# Contributor:
#
#                         Hunter, Thomas - Hunter, Thomas, Approximately 1828-Approximately 1894
#
#
#
# Date:
# : 1874
# [Cat]
# 1 drawing : ink and watercolor. | Ukiyo-e drawing showing a cat.
# ['http://www.loc.gov/item/2005678556/']
# Contributor:
#
#                         Andō, Hiroshige
#
#
#
# Date:
# : 1840
# [Cats]
# 1 negative : glass ; 4 x 5 in. or smaller
# ['http://www.loc.gov/item/2016892680/']
# Contributor:
#
#                         Harris & Ewing
#
#
#
# Date:
# : 1923
# [Cats]
# 1 negative : glass ; 4 x 5 in. or smaller
# ['http://www.loc.gov/item/2016890324/']
# Contributor:
#
#                         Harris & Ewing
#
#
#
# Date:
# : 1934
# [Cat]
# 1 woodcut. | Source - Schreiber collection, folder I -45-98, p. 2.
# ['http://www.loc.gov/item/2018662113/']
# Date:
# : 1569
# [Cat]
# ...
